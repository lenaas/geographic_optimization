# %% [markdown]
# # Geographic Optimization

# %% [markdown]
# ## 1. Distance Calculation
#
# Distances between each of the 16 focus compounds and all approx. 8000 zip codes in Germany.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import pgeocode
import haversine as hs

# %%
import osrm

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Create Dataframes

# %%
zipcodes_df = pd.read_csv('zipcodes.csv',usecols=['zipcode'],dtype='str')
zipcodes_df
# Out:
#      zipcode
# 0      01067
# 1      01069
# 2      01097
# 3      01099
# 4      01108
# ...      ...
# 8169   99988
# 8170   99991
# 8171   99994
# 8172   99996
# 8173   99998
#
# [8174 rows x 1 columns]

# %%
compounds_df = pd.read_csv('compounds_addresses.csv')
compounds_df
# Out:
#             compound_name                                   compound_address
# 0           AKB Kitzingen  AKB Compound Kitzingen, Larson Barracks 53, 97...
# 1            AKB Dortmund  AKB Compound Dortmund, Dammstraße 25, 44145 Do...
# 2              AKB Zörbig  AKB Compound Zörbig, Jeßnitzer Str. 26, 06780 ...
# 3            AKB Schöneck  AKB Compound Schöneck, Windecker Str. 2, 61137...
# 4                AKB Buch  AKB Compound Buch, An der Lehmgrube 1, 89290 Buch
# 5            Mosolf Etzin  ACM Auto-Service und Umschlag-Center Mosolf Et...
# 6       Mosolf Kippenheim    Mosolf Compound, Freimatte 25, 77971 Kippenheim
# 7             BLG Kelheim            Hafenstraße 33, 93342 Saal an der Donau
# 8            BLG Duisburg  BLG AutoTerminal Duisburg GmbH & Co. KG, Rotte...
# 9               BLG Neuss  ATN Autoterminal Neuss, Floßhafenstr. 30, 4146...
# 10      Carservice Erkens  Car Service Erkens, Im Müldersfeld 34, 47669  ...
# 11   ARS Altmann Wolnzach  ARS Altmann AG Automobillogistik, Feierabendmü...
# 12            CAT Zülpich  CAT Compound Zülpich, Richard-Lawson-Straße 1,...
# 13     Autohaus Siebrecht   Autohaus Siebrecht, Wiesenstraße 15, 37170 Uslar
# 14  Neu: FleetParQ Essen                       Joachimstraße 60, 45309 Essen
# 15  Neu: FleetParQ Kassel              Rudolf-Diesel-Straße 13, 34123 Kassel

# %% [markdown]
# #### Convert zip code to longitude and latitude

# %%
nomi = pgeocode.Nominatim('de')

# %%
nomi.query_postal_code(zipcodes_df.iat[0,0])
# Out:
# postal_code                                                   01067
# country_code                                                     DE
# place_name        Dresden Innere Altstadt, Dresden, Dresden Frie...
# state_name                                                  Sachsen
# state_code                                                       SN
# county_name                                                     NaN
# county_code                                                     0.0
# community_name                             Kreisfreie Stadt Dresden
# community_code                                              14612.0
# latitude                                                    51.0547
# longitude                                                   13.7269
# accuracy                                                        4.0
# Name: 0, dtype: object

# %%
for index,row in zipcodes_df.iterrows():
    query = nomi.query_postal_code(zipcodes_df.iat[index,0])
    zipcodes_df.at[index,'lat']= query['latitude']
    zipcodes_df.at[index,'long']= query['longitude']
    zipcodes_df.at[index,'state']= query['state_name']
    zipcodes_df.at[index,'state_code']= query['state_code']
    zipcodes_df.at[index,'community_name']= query['community_name']
    zipcodes_df.at[index,'community_code']= query['community_code']

# %%
compounds_df['zipcode'] = compounds_df['compound_address'].str.findall(r'([0-9]\d+)').apply(lambda x: x[-1] if len(x) >= 1 else '')

# %%
for index,row in compounds_df.iterrows():
    query = nomi.query_postal_code(compounds_df.iat[index,2])
    compounds_df.at[index,'lat']= query['latitude']
    compounds_df.at[index,'long']= query['longitude']

# %%
compounds_df
# Out:
#             compound_name                                   compound_address  \
# 0           AKB Kitzingen  AKB Compound Kitzingen, Larson Barracks 53, 97...
# 1            AKB Dortmund  AKB Compound Dortmund, Dammstraße 25, 44145 Do...
# 2              AKB Zörbig  AKB Compound Zörbig, Jeßnitzer Str. 26, 06780 ...
# 3            AKB Schöneck  AKB Compound Schöneck, Windecker Str. 2, 61137...
# 4                AKB Buch  AKB Compound Buch, An der Lehmgrube 1, 89290 Buch
# 5            Mosolf Etzin  ACM Auto-Service und Umschlag-Center Mosolf Et...
# 6       Mosolf Kippenheim    Mosolf Compound, Freimatte 25, 77971 Kippenheim
# 7             BLG Kelheim            Hafenstraße 33, 93342 Saal an der Donau
# 8            BLG Duisburg  BLG AutoTerminal Duisburg GmbH & Co. KG, Rotte...
# 9               BLG Neuss  ATN Autoterminal Neuss, Floßhafenstr. 30, 4146...
# 10      Carservice Erkens  Car Service Erkens, Im Müldersfeld 34, 47669  ...
# 11   ARS Altmann Wolnzach  ARS Altmann AG Automobillogistik, Feierabendmü...
# 12            CAT Zülpich  CAT Compound Zülpich, Richard-Lawson-Straße 1,...
# 13     Autohaus Siebrecht   Autohaus Siebrecht, Wiesenstraße 15, 37170 Uslar
# 14  Neu: FleetParQ Essen                       Joachimstraße 60, 45309 Essen
# 15  Neu: FleetParQ Kassel              Rudolf-Diesel-Straße 13, 34123 Kassel
#
#    zipcode       lat      long
# 0    97318  49.75320  10.11700
# 1    44145  51.52900   7.48020
# 2    06780  51.61855  12.13373
# 3    61137  50.20560   8.83330
# 4    89290  48.22480  10.18050
# 5    14669  52.48090  12.81490
# 6    77971  48.29560   7.82510
# 7    93342  48.90000  11.93330
# 8    47229  51.39100   6.70710
# 9    41460  51.20140   6.69440
# 10   47669  51.39740   6.29190
# 11   85283  48.60380  11.62570
# 12   53909  50.70000   6.65000
# 13   37170  51.65690   9.63500
# 14   45309  51.48040   7.07140
# 15   34123  51.29880   9.52970

# %% [markdown]
# #### Add coordinate column (necessary for usage of Haversine)

# %%
zipcodes_df['coor']=list(zip(zipcodes_df.lat,zipcodes_df.long))
compounds_df['coor']=list(zip(compounds_df.lat,compounds_df.long))

# %%
zipcodes_df
# Out:
#      zipcode        lat       long      state state_code  \
# 0      01067  51.054700  13.726900    Sachsen         SN
# 1      01069  51.043000  13.737300    Sachsen         SN
# 2      01097  51.071400  13.739900    Sachsen         SN
# 3      01099  51.078300  13.805100    Sachsen         SN
# 4      01108  51.155733  13.782467    Sachsen         SN
# ...      ...        ...        ...        ...        ...
# 8169   99988  51.172900  10.290450  Thüringen         TH
# 8170   99991  51.148467  10.553300  Thüringen         TH
# 8171   99994  51.239850  10.670850  Thüringen         TH
# 8172   99996  51.288800  10.580350  Thüringen         TH
# 8173   99998  51.212500  10.562500  Thüringen         TH
#
#                 community_name  community_code  \
# 0     Kreisfreie Stadt Dresden         14612.0
# 1     Kreisfreie Stadt Dresden         14612.0
# 2     Kreisfreie Stadt Dresden         14612.0
# 3     Kreisfreie Stadt Dresden         14612.0
# 4     Kreisfreie Stadt Dresden         14612.0
# ...                        ...             ...
# 8169     Unstrut-Hainich-Kreis         16064.0
# 8170     Unstrut-Hainich-Kreis         16064.0
# 8171     Unstrut-Hainich-Kreis         16064.0
# 8172     Unstrut-Hainich-Kreis         16064.0
# 8173     Unstrut-Hainich-Kreis         16064.0
#
#                                          coor
# 0                          (51.0547, 13.7269)
# 1                           (51.043, 13.7373)
# 2                          (51.0714, 13.7399)
# 3                          (51.0783, 13.8051)
# 4     (51.15573333333333, 13.782466666666666)
# ...                                       ...
# 8169                      (51.1729, 10.29045)
# 8170             (51.14846666666667, 10.5533)
# 8171                     (51.23985, 10.67085)
# 8172                      (51.2888, 10.58035)
# 8173                       (51.2125, 10.5625)
#
# [8174 rows x 8 columns]

# %% [markdown]
# ### Calculate Distances

# %%
def distance_from(loc1,loc2):
    '''This function defines the distance between customers (loc1) and compound (loc2)'''
    dist = hs.haversine(loc1,loc2)
    return round(dist,2)

# %%
full_distances_df = zipcodes_df.copy()

# %%
for _,row in compounds_df.iterrows():
    full_distances_df[row.compound_name]=full_distances_df['coor'].apply(lambda x: distance_from(row['coor'],x))

# %%
distances = full_distances_df.drop(columns=['lat','long','coor'],axis=1)

# %%
distances.set_index('zipcode', inplace=True)

# %%
distances
# Out:
#              state state_code            community_name  community_code  \
# zipcode
# 01067      Sachsen         SN  Kreisfreie Stadt Dresden         14612.0
# 01069      Sachsen         SN  Kreisfreie Stadt Dresden         14612.0
# 01097      Sachsen         SN  Kreisfreie Stadt Dresden         14612.0
# 01099      Sachsen         SN  Kreisfreie Stadt Dresden         14612.0
# 01108      Sachsen         SN  Kreisfreie Stadt Dresden         14612.0
# ...            ...        ...                       ...             ...
# 99988    Thüringen         TH     Unstrut-Hainich-Kreis         16064.0
# 99991    Thüringen         TH     Unstrut-Hainich-Kreis         16064.0
# 99994    Thüringen         TH     Unstrut-Hainich-Kreis         16064.0
# 99996    Thüringen         TH     Unstrut-Hainich-Kreis         16064.0
# 99998    Thüringen         TH     Unstrut-Hainich-Kreis         16064.0
#
#          AKB Kitzingen  AKB Dortmund  AKB Zörbig  AKB Schöneck  AKB Buch  \
# zipcode
# 01067           293.89        437.43      127.20        357.77    405.16
# 01069           293.92        438.36      128.48        358.18    404.64
# 01097           295.57        438.02      127.07        359.08    407.16
# 01099           299.95        442.40      130.70        363.69    410.71
# 01108           302.71        439.58      125.45        364.28    416.25
# ...                ...           ...         ...           ...       ...
# 99988           158.34        199.13      137.14        148.67    327.91
# 99991           158.19        217.61      121.49        160.24    326.20
# 99994           169.89        223.72      109.81        173.07    337.10
# 99996           173.86        216.66      113.71        172.08    341.91
# 99998           165.30        216.82      117.94        165.40    333.35
#
#          Mosolf Etzin  Mosolf Kippenheim  BLG Kelheim  BLG Duisburg  \
# zipcode
# 01067          170.55             523.64       271.74        490.10
# 01069          172.02             523.53       270.96        490.99
# 01097          169.15             525.43       273.81        490.78
# 01099          170.19             529.65       276.70        495.21
# 01108          161.66             533.13       283.46        492.70
# ...               ...                ...          ...           ...
# 99988          226.36             365.68       278.63        250.38
# 99991          214.74             372.89       268.74        268.90
# 99994          201.78             385.88       275.33        275.96
# 99996          202.70             387.09       282.60        269.26
# 99998          209.34             379.24       275.12        268.73
#
#          BLG Neuss  Carservice Erkens  ARS Altmann Wolnzach  CAT Zülpich  \
# zipcode
# 01067       490.84             518.92                311.40       497.90
# 01069       491.67             519.80                310.63       498.59
# 01097       491.60             519.59                313.46       498.87
# 01099       496.08             524.02                316.41       503.45
# 01108       493.93             521.50                323.08       502.25
# ...            ...                ...                   ...          ...
# 99988       250.62             279.17                301.25       260.43
# 99991       269.05             297.69                293.20       278.06
# 99994       276.94             304.78                300.97       287.84
# 99996       270.63             298.07                307.78       282.71
# 99998       269.44             297.55                299.89       279.87
#
#          Autohaus Siebrecht  Neu: FleetParQ Essen   Neu: FleetParQ Kassel
# zipcode
# 01067                291.88                 465.29                 293.80
# 01069                292.92                 466.20                 294.69
# 01097                292.29                 465.92                 294.49
# 01099                296.51                 470.32                 298.93
# 01108                292.98                 467.63                 296.52
# ...                     ...                    ...                    ...
# 99988                 70.45                 226.25                  54.78
# 99991                 85.17                 244.77                  73.22
# 99994                 85.46                 251.32                  79.66
# 99996                 77.22                 244.41                  73.06
# 99998                 81.09                 244.27                  72.51
#
# [8174 rows x 20 columns]

# %% [markdown]
# Result:
# For every zipcode, the distances (in km) to every compound are given.
# As it's stored in a pandas Dataframe, further investigations can be easily done (p.eg. seeing the minimum per row etc.).

# %% [markdown]
# ### Calculate Driving Distance

# %%
import osrm
import requests
import json

# %%
zipcodes_df_split = np.array_split(zipcodes_df,100)
zipcodes_df_split[0]
# Out:
#    zipcode        lat       long    state state_code  \
# 0    01067  51.054700  13.726900  Sachsen         SN
# 1    01069  51.043000  13.737300  Sachsen         SN
# 2    01097  51.071400  13.739900  Sachsen         SN
# 3    01099  51.078300  13.805100  Sachsen         SN
# 4    01108  51.155733  13.782467  Sachsen         SN
# ..     ...        ...        ...      ...        ...
# 77   01855  50.959350  14.261250  Sachsen         SN
# 78   01877  51.131600  14.247900  Sachsen         SN
# 79   01896  51.179500  14.009200  Sachsen         SN
# 80   01900  51.147650  14.051250  Sachsen         SN
# 81   01904  51.080200  14.326650  Sachsen         SN
#
#                   community_name  community_code  \
# 0       Kreisfreie Stadt Dresden         14612.0
# 1       Kreisfreie Stadt Dresden         14612.0
# 2       Kreisfreie Stadt Dresden         14612.0
# 3       Kreisfreie Stadt Dresden         14612.0
# 4       Kreisfreie Stadt Dresden         14612.0
# ..                           ...             ...
# 77  Landkreis Sächsische Schweiz         14628.0
# 78             Landkreis Bautzen         14625.0
# 79             Landkreis Bautzen         14625.0
# 80             Landkreis Bautzen         14625.0
# 81             Landkreis Bautzen         14625.0
#
#                                         coor
# 0                         (51.0547, 13.7269)
# 1                          (51.043, 13.7373)
# 2                         (51.0714, 13.7399)
# 3                         (51.0783, 13.8051)
# 4    (51.15573333333333, 13.782466666666666)
# ..                                       ...
# 77                      (50.95935, 14.26125)
# 78  (51.131600000000006, 14.247899999999998)
# 79                        (51.1795, 14.0092)
# 80                      (51.14765, 14.05125)
# 81                       (51.0802, 14.32665)
#
# [82 rows x 8 columns]

# %%
zipcodes_df_split[0]
# Out:
#    zipcode        lat       long    state state_code  \
# 0    01067  51.054700  13.726900  Sachsen         SN
# 1    01069  51.043000  13.737300  Sachsen         SN
# 2    01097  51.071400  13.739900  Sachsen         SN
# 3    01099  51.078300  13.805100  Sachsen         SN
# 4    01108  51.155733  13.782467  Sachsen         SN
# ..     ...        ...        ...      ...        ...
# 77   01855  50.959350  14.261250  Sachsen         SN
# 78   01877  51.131600  14.247900  Sachsen         SN
# 79   01896  51.179500  14.009200  Sachsen         SN
# 80   01900  51.147650  14.051250  Sachsen         SN
# 81   01904  51.080200  14.326650  Sachsen         SN
#
#                   community_name  community_code  \
# 0       Kreisfreie Stadt Dresden         14612.0
# 1       Kreisfreie Stadt Dresden         14612.0
# 2       Kreisfreie Stadt Dresden         14612.0
# 3       Kreisfreie Stadt Dresden         14612.0
# 4       Kreisfreie Stadt Dresden         14612.0
# ..                           ...             ...
# 77  Landkreis Sächsische Schweiz         14628.0
# 78             Landkreis Bautzen         14625.0
# 79             Landkreis Bautzen         14625.0
# 80             Landkreis Bautzen         14625.0
# 81             Landkreis Bautzen         14625.0
#
#                                         coor
# 0                         (51.0547, 13.7269)
# 1                          (51.043, 13.7373)
# 2                         (51.0714, 13.7399)
# 3                         (51.0783, 13.8051)
# 4    (51.15573333333333, 13.782466666666666)
# ..                                       ...
# 77                      (50.95935, 14.26125)
# 78  (51.131600000000006, 14.247899999999998)
# 79                        (51.1795, 14.0092)
# 80                      (51.14765, 14.05125)
# 81                       (51.0802, 14.32665)
#
# [82 rows x 8 columns]

# %%
import requests
import json
from tqdm import tqdm

# %%
def request_driving_distance_in_meters_from_api(loc1,loc2):
    '''Requests from OpenStreetMap to calculate Driving Distance between customer and compound'''
    r = requests.get(f"""http://router.project-osrm.org/route/v1/car/{loc1[1]},{loc1[0]};{loc2[1]},{loc2[0]}?overview=false""")
    content = json.loads(r.content)
    if 'routes' in content:
        route_1 = content['routes'][0]
        return route_1['distance']
    else:
        return 0.0

# %%
zipcodes_df_split = np.array_split(zipcodes_df,100)
zipcodes_df_split[0]
# Out:
#    zipcode        lat       long    state state_code  \
# 0    01067  51.054700  13.726900  Sachsen         SN
# 1    01069  51.043000  13.737300  Sachsen         SN
# 2    01097  51.071400  13.739900  Sachsen         SN
# 3    01099  51.078300  13.805100  Sachsen         SN
# 4    01108  51.155733  13.782467  Sachsen         SN
# ..     ...        ...        ...      ...        ...
# 77   01855  50.959350  14.261250  Sachsen         SN
# 78   01877  51.131600  14.247900  Sachsen         SN
# 79   01896  51.179500  14.009200  Sachsen         SN
# 80   01900  51.147650  14.051250  Sachsen         SN
# 81   01904  51.080200  14.326650  Sachsen         SN
#
#                   community_name  community_code  \
# 0       Kreisfreie Stadt Dresden         14612.0
# 1       Kreisfreie Stadt Dresden         14612.0
# 2       Kreisfreie Stadt Dresden         14612.0
# 3       Kreisfreie Stadt Dresden         14612.0
# 4       Kreisfreie Stadt Dresden         14612.0
# ..                           ...             ...
# 77  Landkreis Sächsische Schweiz         14628.0
# 78             Landkreis Bautzen         14625.0
# 79             Landkreis Bautzen         14625.0
# 80             Landkreis Bautzen         14625.0
# 81             Landkreis Bautzen         14625.0
#
#                                         coor
# 0                         (51.0547, 13.7269)
# 1                          (51.043, 13.7373)
# 2                         (51.0714, 13.7399)
# 3                         (51.0783, 13.8051)
# 4    (51.15573333333333, 13.782466666666666)
# ..                                       ...
# 77                      (50.95935, 14.26125)
# 78  (51.131600000000006, 14.247899999999998)
# 79                        (51.1795, 14.0092)
# 80                      (51.14765, 14.05125)
# 81                       (51.0802, 14.32665)
#
# [82 rows x 8 columns]

# %%
tqdm.pandas()

for i in range(55,100):
    driving_distances_df = zipcodes_df_split[i]
    for _,row in compounds_df.iterrows():
        driving_distances_df[row.compound_name]=driving_distances_df['coor'].progress_apply(lambda x: request_driving_distance_in_meters_from_api(row['coor'],x))
    driving_distances_df.to_csv(f'csv_{i}')
# Out:
# 100%|██████████| 82/82 [00:40<00:00,  2.02it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.01it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.01it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.01it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.94it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.94it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.98it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.94it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.99it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.01it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.99it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.94it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.98it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.99it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.96it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.94it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.99it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.98it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.98it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.95it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.95it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.94it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.95it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.01it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.94it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.94it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.01it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.98it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.94it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:42<00:00,  1.92it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.98it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.99it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:40<00:00,  2.00it/s]
# 100%|██████████| 82/82 [00:41<00:00,  1.97it/s]
# 100%|██████████| 82/82 [00:41<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.98it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.96it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  1.98it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.96it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.95it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:42<00:00,  1.90it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:42<00:00,  1.90it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.95it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:42<00:00,  1.92it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  1.99it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:42<00:00,  1.93it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  1.99it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  1.98it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:42<00:00,  1.89it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.96it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.95it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.93it/s]
# 100%|██████████| 81/81 [00:42<00:00,  1.92it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.95it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.94it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:41<00:00,  1.97it/s]
# 100%|██████████| 81/81 [00:43<00:00,  1.86it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  1.98it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  1.99it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.01it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]
# 100%|██████████| 81/81 [00:40<00:00,  2.00it/s]

# %%
import pandas as pd 
import glob
import os 

files = os.path.join("csv_*")
files = glob.glob(files)
files.sort()
print(len(files))

driving_distances_complete_df = pd.concat(map(pd.read_csv,files), ignore_index=True)
# Out:
# 100

# %%
driving_distances_complete_df=driving_distances_complete_df.loc[:, ~driving_distances_complete_df.columns.str.contains('^Unnamed')]
driving_distances_complete_df
# Out:
#       zipcode        lat       long      state state_code  \
# 0        1067  51.054700  13.726900    Sachsen         SN
# 1        1069  51.043000  13.737300    Sachsen         SN
# 2        1097  51.071400  13.739900    Sachsen         SN
# 3        1099  51.078300  13.805100    Sachsen         SN
# 4        1108  51.155733  13.782467    Sachsen         SN
# ...       ...        ...        ...        ...        ...
# 8169    99988  51.172900  10.290450  Thüringen         TH
# 8170    99991  51.148467  10.553300  Thüringen         TH
# 8171    99994  51.239850  10.670850  Thüringen         TH
# 8172    99996  51.288800  10.580350  Thüringen         TH
# 8173    99998  51.212500  10.562500  Thüringen         TH
#
#                 community_name  community_code  \
# 0     Kreisfreie Stadt Dresden         14612.0
# 1     Kreisfreie Stadt Dresden         14612.0
# 2     Kreisfreie Stadt Dresden         14612.0
# 3     Kreisfreie Stadt Dresden         14612.0
# 4     Kreisfreie Stadt Dresden         14612.0
# ...                        ...             ...
# 8169     Unstrut-Hainich-Kreis         16064.0
# 8170     Unstrut-Hainich-Kreis         16064.0
# 8171     Unstrut-Hainich-Kreis         16064.0
# 8172     Unstrut-Hainich-Kreis         16064.0
# 8173     Unstrut-Hainich-Kreis         16064.0
#
#                                          coor  AKB Kitzingen  AKB Dortmund  \
# 0                          (51.0547, 13.7269)       373603.4      516385.5
# 1                           (51.043, 13.7373)       380443.6      523225.7
# 2                          (51.0714, 13.7399)       374843.4      517625.5
# 3                          (51.0783, 13.8051)       379475.1      522257.3
# 4     (51.15573333333333, 13.782466666666666)       388473.1      531255.2
# ...                                       ...            ...           ...
# 8169                      (51.1729, 10.29045)       236530.0      238432.6
# 8170             (51.14846666666667, 10.5533)       206039.6      281053.1
# 8171                     (51.23985, 10.67085)       214849.2      281926.4
# 8172                      (51.2888, 10.58035)       224226.0      271339.6
# 8173                       (51.2125, 10.5625)       224273.8      278282.1
#
#       ...  Mosolf Kippenheim  BLG Kelheim  BLG Duisburg  BLG Neuss  \
# 0     ...           643658.1     359656.4      595466.6   584338.6
# 1     ...           650498.3     366496.6      602306.8   591178.8
# 2     ...           644898.1     360896.4      596706.6   585578.6
# 3     ...           649529.8     365528.2      601338.4   590210.3
# 4     ...           658527.8     374526.1      610336.3   599208.3
# ...   ...                ...          ...           ...        ...
# 8169  ...           440296.6     371541.1      317513.7   306385.6
# 8170  ...           455404.1     346407.4      360134.2   349006.2
# 8171  ...           465939.5     355217.0      361007.5   349879.4
# 8172  ...           465161.6     364593.8      350420.7   339292.6
# 8173  ...           458251.9     364641.6      357363.2   346235.2
#
#       Carservice Erkens  ARS Altmann Wolnzach  CAT Zülpich  \
# 0              622440.7              405654.5     617219.9
# 1              629280.9              412494.7     624060.1
# 2              623680.7              406894.5     618459.9
# 3              628312.4              411526.2     623091.6
# 4              637310.4              420524.2     632089.6
# ...                 ...                   ...          ...
# 8169           344487.8              379233.9     352974.2
# 8170           387108.3              354100.2     385883.3
# 8171           387981.6              362909.8     396468.0
# 8172           377394.8              372286.7     385881.2
# 8173           384337.3              372334.5     392823.7
#
#       Autohaus Siebrecht  Neu: FleetParQ Essen   Neu: FleetParQ Kassel
# 0               354548.1               553037.3               350318.7
# 1               361388.3               559877.5               357158.9
# 2               355788.1               554277.3               351558.7
# 3               360419.8               558909.0               356190.5
# 4               369417.8               567907.0               365188.4
# ...                  ...                    ...                    ...
# 8169             99709.5               275084.4                71862.1
# 8170            119215.7               317704.9               114986.3
# 8171            120089.0               318578.2               115859.6
# 8172            109502.2               307991.4               105272.8
# 8173            116444.7               314933.9               112215.3
#
# [8174 rows x 24 columns]

# %%
driving_distances_complete_df.to_csv('driving_distances_complete_in_meters.csv')

# %%
distances_km_df = driving_distances_complete_df.copy()
distances_km_df
# Out:
#       zipcode        lat       long      state state_code  \
# 0        1067  51.054700  13.726900    Sachsen         SN
# 1        1069  51.043000  13.737300    Sachsen         SN
# 2        1097  51.071400  13.739900    Sachsen         SN
# 3        1099  51.078300  13.805100    Sachsen         SN
# 4        1108  51.155733  13.782467    Sachsen         SN
# ...       ...        ...        ...        ...        ...
# 8169    99988  51.172900  10.290450  Thüringen         TH
# 8170    99991  51.148467  10.553300  Thüringen         TH
# 8171    99994  51.239850  10.670850  Thüringen         TH
# 8172    99996  51.288800  10.580350  Thüringen         TH
# 8173    99998  51.212500  10.562500  Thüringen         TH
#
#                 community_name  community_code  \
# 0     Kreisfreie Stadt Dresden         14612.0
# 1     Kreisfreie Stadt Dresden         14612.0
# 2     Kreisfreie Stadt Dresden         14612.0
# 3     Kreisfreie Stadt Dresden         14612.0
# 4     Kreisfreie Stadt Dresden         14612.0
# ...                        ...             ...
# 8169     Unstrut-Hainich-Kreis         16064.0
# 8170     Unstrut-Hainich-Kreis         16064.0
# 8171     Unstrut-Hainich-Kreis         16064.0
# 8172     Unstrut-Hainich-Kreis         16064.0
# 8173     Unstrut-Hainich-Kreis         16064.0
#
#                                          coor  AKB Kitzingen  AKB Dortmund  \
# 0                          (51.0547, 13.7269)       373603.4      516385.5
# 1                           (51.043, 13.7373)       380443.6      523225.7
# 2                          (51.0714, 13.7399)       374843.4      517625.5
# 3                          (51.0783, 13.8051)       379475.1      522257.3
# 4     (51.15573333333333, 13.782466666666666)       388473.1      531255.2
# ...                                       ...            ...           ...
# 8169                      (51.1729, 10.29045)       236530.0      238432.6
# 8170             (51.14846666666667, 10.5533)       206039.6      281053.1
# 8171                     (51.23985, 10.67085)       214849.2      281926.4
# 8172                      (51.2888, 10.58035)       224226.0      271339.6
# 8173                       (51.2125, 10.5625)       224273.8      278282.1
#
#       ...  Mosolf Kippenheim  BLG Kelheim  BLG Duisburg  BLG Neuss  \
# 0     ...           643658.1     359656.4      595466.6   584338.6
# 1     ...           650498.3     366496.6      602306.8   591178.8
# 2     ...           644898.1     360896.4      596706.6   585578.6
# 3     ...           649529.8     365528.2      601338.4   590210.3
# 4     ...           658527.8     374526.1      610336.3   599208.3
# ...   ...                ...          ...           ...        ...
# 8169  ...           440296.6     371541.1      317513.7   306385.6
# 8170  ...           455404.1     346407.4      360134.2   349006.2
# 8171  ...           465939.5     355217.0      361007.5   349879.4
# 8172  ...           465161.6     364593.8      350420.7   339292.6
# 8173  ...           458251.9     364641.6      357363.2   346235.2
#
#       Carservice Erkens  ARS Altmann Wolnzach  CAT Zülpich  \
# 0              622440.7              405654.5     617219.9
# 1              629280.9              412494.7     624060.1
# 2              623680.7              406894.5     618459.9
# 3              628312.4              411526.2     623091.6
# 4              637310.4              420524.2     632089.6
# ...                 ...                   ...          ...
# 8169           344487.8              379233.9     352974.2
# 8170           387108.3              354100.2     385883.3
# 8171           387981.6              362909.8     396468.0
# 8172           377394.8              372286.7     385881.2
# 8173           384337.3              372334.5     392823.7
#
#       Autohaus Siebrecht  Neu: FleetParQ Essen   Neu: FleetParQ Kassel
# 0               354548.1               553037.3               350318.7
# 1               361388.3               559877.5               357158.9
# 2               355788.1               554277.3               351558.7
# 3               360419.8               558909.0               356190.5
# 4               369417.8               567907.0               365188.4
# ...                  ...                    ...                    ...
# 8169             99709.5               275084.4                71862.1
# 8170            119215.7               317704.9               114986.3
# 8171            120089.0               318578.2               115859.6
# 8172            109502.2               307991.4               105272.8
# 8173            116444.7               314933.9               112215.3
#
# [8174 rows x 24 columns]

# %%
def convert_meters_to_kilometers(x):
    return x/1000

# %%
distances_km_df.iloc[:,8:]=distances_km_df.iloc[:,8:].apply(convert_meters_to_kilometers,axis=1)

# %%
distances_km_df.to_csv('distances_complete_in_kilometers.csv')

# %% [markdown]
# ## 3. Heatmap
#
# Visualize which cars are demanded by which customers in which regions of Germany.

# %%
analysis_input_df = pd.read_csv('zip_code_analysis_input.csv',usecols=['sub_property_handover_zipcode','sub_property_handover_city','abs_net_purchase_price','brand_name','config_model_name','finn_car_id','deal_id','dim_fkey_pipelinestage','product_brand','purchasing_model','purchasing_model_line','product_fuel','helper_subscription_handover_date','product_body_type','delivery_compound_location'],dtype='str')
analysis_input_df=analysis_input_df.rename(columns={'sub_property_handover_zipcode':'zipcode'})

# %%
full_geodata_df = pd.merge(zipcodes_df,analysis_input_df,how='inner',on='zipcode')
full_geodata_df
# Out:
#       zipcode        lat       long      state state_code  \
# 0       01067  51.054700  13.726900    Sachsen         SN
# 1       01067  51.054700  13.726900    Sachsen         SN
# 2       01067  51.054700  13.726900    Sachsen         SN
# 3       01069  51.043000  13.737300    Sachsen         SN
# 4       01069  51.043000  13.737300    Sachsen         SN
# ...       ...        ...        ...        ...        ...
# 13882   99869  50.967996  10.706304  Thüringen         TH
# 13883   99880  50.930420  10.585770  Thüringen         TH
# 13884   99885  50.806800  10.748833  Thüringen         TH
# 13885   99976  51.247783  10.328933  Thüringen         TH
# 13886   99976  51.247783  10.328933  Thüringen         TH
#
#                  community_name  community_code  \
# 0      Kreisfreie Stadt Dresden         14612.0
# 1      Kreisfreie Stadt Dresden         14612.0
# 2      Kreisfreie Stadt Dresden         14612.0
# 3      Kreisfreie Stadt Dresden         14612.0
# 4      Kreisfreie Stadt Dresden         14612.0
# ...                         ...             ...
# 13882           Landkreis Gotha         16067.0
# 13883           Landkreis Gotha         16067.0
# 13884           Landkreis Gotha         16067.0
# 13885     Unstrut-Hainich-Kreis         16064.0
# 13886     Unstrut-Hainich-Kreis         16064.0
#
#                                           coor sub_property_handover_city  \
# 0                           (51.0547, 13.7269)                    Dresden
# 1                           (51.0547, 13.7269)                    Dresden
# 2                           (51.0547, 13.7269)                    Dresden
# 3                            (51.043, 13.7373)           Dresden, Sachsen
# 4                            (51.043, 13.7373)                   Dresden
# ...                                        ...                        ...
# 13882  (50.96799642857143, 10.706303571428572)   Drei Gleichen OT Wechmar
# 13883                     (50.93042, 10.58577)              Waltershausen
# 13884            (50.8068, 10.748833333333332)                    Ohrdruf
# 13885  (51.24778333333333, 10.328933333333334)                   Rodeberg
# 13886  (51.24778333333333, 10.328933333333334)         Rodeberg OT Struth
#
#       abs_net_purchase_price  ... finn_car_id      deal_id  \
# 0                        NaN  ...    etw8hl87   6746684805
# 1                   39451.41  ...    awmj43ax  10031089330
# 2                   23138.83  ...    6a4y4psd   8264850799
# 3                        NaN  ...    w2riqyps   5364503057
# 4                   28588.52  ...    jsuh5jig   9185094506
# ...                      ...  ...         ...          ...
# 13882                    NaN  ...    p30d722d  10720063262
# 13883                    NaN  ...    g23xc8qu   4663230905
# 13884                    NaN  ...    g1durj3r   6297457305
# 13885               15061.95  ...    2atzum4f   8916763229
# 13886               44722.69  ...    cfjk4nq2  10473801606
#
#       dim_fkey_pipelinestage product_brand purchasing_model  \
# 0                    1319394          Fiat              NaN
# 1                    1050363           NaN              NaN
# 2                    1050363           NaN              NaN
# 3                    1319394          Fiat              NaN
# 4                    1050363           NaN              NaN
# ...                      ...           ...              ...
# 13882                1050363          Opel              NaN
# 13883                1319394          Jeep              NaN
# 13884                1319394           NaN              NaN
# 13885                1050363           NaN              NaN
# 13886                1050363           NaN              NaN
#
#       purchasing_model_line product_fuel helper_subscription_handover_date  \
# 0                       NaN          NaN                               NaN
# 1                       NaN          NaN                               NaN
# 2                       NaN          NaN                               NaN
# 3                       NaN          NaN                               NaN
# 4                       NaN          NaN                               NaN
# ...                     ...          ...                               ...
# 13882                   NaN          NaN                               NaN
# 13883                   NaN          NaN                               NaN
# 13884                   NaN          NaN                               NaN
# 13885                   NaN          NaN                               NaN
# 13886                   NaN          NaN                               NaN
#
#       product_body_type delivery_compound_location
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                   NaN                        NaN
# ...                 ...                        ...
# 13882               NaN                        NaN
# 13883               NaN                        NaN
# 13884               NaN                        NaN
# 13885               NaN                        NaN
# 13886               NaN                        NaN
#
# [13887 rows x 22 columns]

# %%
airtable_df = pd.read_csv('airtable_data.csv',dtype='str')
airtable_df
# Out:
#       finn_car_id product_brand purchasing_model  purchasing_model_line  \
# 0        0a0jlxzj          Opel        Crossland                Edition
# 1        0a4q0kww       Renault           Koleos                 Intens
# 2        0a5aqavf          Jeep          Compass                 Upland
# 3        0a5o8f6t          Audi               Q3                 S line
# 4        0a6jwfvb        Nissan          Qashqai                 Acenta
# ...           ...           ...              ...                    ...
# 42181    zzx60fa5           BMW      3er Touring           M Automobile
# 42182    zzyasour          Jeep          Compass                Limited
# 42183    zzyg5ckg          Opel        Grandland                GS Line
# 42184    zzz1n8rw            VW   Caravelle T6 1         Comfortline LR
# 42185    zzzs9a5t       Hyundai     KONA Elektro  Trend – Facelift 2021
#
#                product_fuel helper_subscription_handover_date  \
# 0                    Benzin                               NaN
# 1                    Benzin                        2022-10-24
# 2            Plug-In-Hybrid                               NaN
# 3      Benzin (mild-hybrid)                               NaN
# 4      Benzin (mild-hybrid)                        2022-06-02
# ...                     ...                               ...
# 42181                Diesel                        2022-11-21
# 42182                Benzin                        2022-06-28
# 42183                Benzin                               NaN
# 42184                Diesel                        2023-02-09
# 42185               Elektro                        2022-10-07
#
#       product_body_type   delivery_compound_location
# 0                   SUV  compound_blg_saalanderdonau
# 1                   SUV          compound_rrg_eching
# 2                   SUV   compound_mosolf_kippenheim
# 3                   SUV       compound_akb_kitzingen
# 4                   SUV  compound_blg_d2c_atn2_neuss
# ...                 ...                          ...
# 42181             Kombi       compound_akb_kitzingen
# 42182               SUV   compound_mosolf_kippenheim
# 42183               SUV   dealer_siebrecht_d2c_uslar
# 42184               Van       compound_akb_kitzingen
# 42185               SUV  compound_blg_saalanderdonau
#
# [42186 rows x 8 columns]

# %%
full_joined_df = pd.merge(full_geodata_df,airtable_df,how='inner',on='finn_car_id')
full_joined_df
# Out:
#       zipcode        lat       long      state state_code  \
# 0       01067  51.054700  13.726900    Sachsen         SN
# 1       97892  49.768200   9.518200     Bayern         BY
# 2       01067  51.054700  13.726900    Sachsen         SN
# 3       01067  51.054700  13.726900    Sachsen         SN
# 4       01069  51.043000  13.737300    Sachsen         SN
# ...       ...        ...        ...        ...        ...
# 13881   99834  50.968875  10.142300  Thüringen         TH
# 13882   99867  50.948200  10.701900  Thüringen         TH
# 13883   99867  50.948200  10.701900  Thüringen         TH
# 13884   99976  51.247783  10.328933  Thüringen         TH
# 13885   99976  51.247783  10.328933  Thüringen         TH
#
#                  community_name  community_code  \
# 0      Kreisfreie Stadt Dresden         14612.0
# 1                 Main-Spessart          9677.0
# 2      Kreisfreie Stadt Dresden         14612.0
# 3      Kreisfreie Stadt Dresden         14612.0
# 4      Kreisfreie Stadt Dresden         14612.0
# ...                         ...             ...
# 13881             Wartburgkreis         16063.0
# 13882           Landkreis Gotha         16067.0
# 13883           Landkreis Gotha         16067.0
# 13884     Unstrut-Hainich-Kreis         16064.0
# 13885     Unstrut-Hainich-Kreis         16064.0
#
#                                           coor sub_property_handover_city  \
# 0                           (51.0547, 13.7269)                    Dresden
# 1                            (49.7682, 9.5182)              Kreuzwertheim
# 2                           (51.0547, 13.7269)                    Dresden
# 3                           (51.0547, 13.7269)                    Dresden
# 4                            (51.043, 13.7373)           Dresden, Sachsen
# ...                                        ...                        ...
# 13881                     (50.968875, 10.1423)                 Gerstungen
# 13882                       (50.9482, 10.7019)                      Gotha
# 13883                       (50.9482, 10.7019)                      Gotha
# 13884  (51.24778333333333, 10.328933333333334)                   Rodeberg
# 13885  (51.24778333333333, 10.328933333333334)         Rodeberg OT Struth
#
#       abs_net_purchase_price  ... helper_subscription_handover_date_x  \
# 0                        NaN  ...                                 NaN
# 1                        NaN  ...                                 NaN
# 2                   39451.41  ...                                 NaN
# 3                   23138.83  ...                                 NaN
# 4                        NaN  ...                                 NaN
# ...                      ...  ...                                 ...
# 13881                      0  ...                                 NaN
# 13882                    NaN  ...                                 NaN
# 13883                    NaN  ...                                 NaN
# 13884               15061.95  ...                                 NaN
# 13885               44722.69  ...                                 NaN
#
#       product_body_type_x delivery_compound_location_x product_brand_y  \
# 0                     NaN                          NaN            Fiat
# 1                     NaN                          NaN            Fiat
# 2                     NaN                          NaN             BMW
# 3                     NaN                          NaN          Nissan
# 4                     NaN                          NaN            Fiat
# ...                   ...                          ...             ...
# 13881                 NaN                          NaN              VW
# 13882                 NaN                          NaN            Jeep
# 13883                 NaN                          NaN            Jeep
# 13884                 NaN                          NaN            Opel
# 13885                 NaN                          NaN           Tesla
#
#       purchasing_model_y purchasing_model_line_y        product_fuel_y  \
# 0                  500 e                    ICON               Elektro
# 1                  500 e                    ICON               Elektro
# 2          3er Limousine            M Sportpaket                Benzin
# 3                Qashqai                  Acenta  Benzin (mild-hybrid)
# 4                  500 e                    ICON               Elektro
# ...                  ...                     ...                   ...
# 13881     Passat Variant                Business                Benzin
# 13882            Compass                 Limited                Benzin
# 13883            Compass                 Limited                Benzin
# 13884          Crossland                 GS Line                Benzin
# 13885            Model Y              Long Range               Elektro
#
#       helper_subscription_handover_date_y product_body_type_y  \
# 0                              2022-07-06          Kleinwagen
# 1                              2022-07-06          Kleinwagen
# 2                              2022-10-04           Limousine
# 3                              2022-03-29                 SUV
# 4                              2022-10-18          Kleinwagen
# ...                                   ...                 ...
# 13881                          2023-01-17               Kombi
# 13882                          2022-05-09                 SUV
# 13883                          2022-04-20                 SUV
# 13884                          2022-07-06                 SUV
# 13885                          2022-11-08                 SUV
#
#        delivery_compound_location_y
# 0        compound_mosolf_kippenheim
# 1        compound_mosolf_kippenheim
# 2            compound_akb_kitzingen
# 3       compound_blg_d2c_atn2_neuss
# 4        compound_mosolf_kippenheim
# ...                             ...
# 13881  compound_arsaltmann_wolnzach
# 13882    compound_mosolf_kippenheim
# 13883    compound_mosolf_kippenheim
# 13884    dealer_siebrecht_d2c_uslar
# 13885        compound_akb_kitzingen
#
# [13886 rows x 29 columns]

# %%
from bokeh.models import *
from bokeh.plotting import *
from bokeh.io import *
from bokeh.tile_providers import *
from bokeh.palettes import *
from bokeh.transform import *
from bokeh.layouts import *
# Out:
# BokehDeprecationWarning: tile_providers module was deprecated in Bokeh 3.0.0 and will be removed, use add_tile directly instead.

# %%
full_joined_df['lat']=full_joined_df['lat'].astype('float')
full_joined_df['long']=full_joined_df['long'].astype('float')

# %%
#Bokeh maps are in mercator. Convert lat lon fields to mercator units for plotting

def wgs84_to_web_mercator(df, lon, lat):
    """Converts decimal longitude/latitude to Web Mercator format"""
    k = 6378137
    df["x"] = df[lon] * (k * np.pi/180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi/360.0)) * k
    return df

df=wgs84_to_web_mercator(full_joined_df,'long','lat')

# %%
#Establishing a zoom scale for the map. The scale variable will also determine proportions for hexbins and bubble maps so that everything looks visually appealing. 

scale=2000
x=df['x']
y=df['y']

#The range for the map extents is derived from the lat/lon fields. This way the map is automatically centered on the plot elements.

x_min=int(x.mean() - (scale * 350))
x_max=int(x.mean() + (scale * 350))
y_min=int(y.mean() - (scale * 350))
y_max=int(y.mean() + (scale * 350))

#Defining the map tiles to use. I use OSM, but you can also use ESRI images or google street maps.


#Establish the bokeh plot object and add the map tile as an underlay. Hide x and y axis.

plot=figure(
    title='Location of Customers',
    match_aspect=True,
    tools='wheel_zoom,pan,reset,save',
    x_range=(x_min, x_max),
    y_range=(y_min, y_max),
    x_axis_type='mercator',
    y_axis_type='mercator'
    )

plot.grid.visible=True

map=plot.add_tile('OSM',retina=True)
map.level='underlay'

plot.xaxis.visible = False
plot.yaxis.visible=False

#If in Jupyter, use the output_notebook() method to display the plot in-line. If not, you can use output_file() or another method to save your map. 
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1280">Loading BokehJS ...</span>
#     </div>

# %%
#function takes scale (defined above), the initialized plot object, and the converted dataframe with mercator coordinates to create a hexbin map

def hex_map(plot,df, scale,leg_label='Hexbin Heatmap'):
  r,bins=plot.hexbin(x,y,size=scale*10,hover_color='pink',hover_alpha=0.8,legend_label=leg_label)
  hex_hover = HoverTool(tooltips=[('count','@c')],mode='mouse',point_policy='follow_mouse',renderers=[r])
  hex_hover.renderers.append(r)
  plot.tools.append(hex_hover)
  
  plot.legend.location = "top_right"
  plot.legend.click_policy="hide"

#function takes a column to determine radius and the dataframe with converted mercator coordinates to create a bubble map. 
def bubble_map(plot,df,radius_col,long,lat,scale,color='orange',leg_label='Bubble Map'):
  radius=[]
  for i in df[radius_col]:
    radius.append(i*scale)
  
  df['radius']=radius
    
  source=ColumnDataSource(df)
  c=plot.circle(x='x',y='y',color=color,source=source,size=1,fill_alpha=0.4,radius='radius',legend_label=leg_label,hover_color='red')

  tip_label='@'+radius_col
  lat_label='@'+lat
  lon_label='@'+long

  circle_hover = HoverTool(tooltips=[(radius_col,tip_label),('Lat:',lat_label),('Long:',lon_label)],mode='mouse',point_policy='follow_mouse',renderers=[c])
  circle_hover.renderers.append(c)
  plot.tools.append(circle_hover)

#The legend.click_policy method allows us to toggle layer on/off by clicking the corresponding field in the legend. We'll explore this more later!
  plot.legend.location = "top_right"
  plot.legend.click_policy="hide"

# %%
count_per_zipcode = full_joined_df[['finn_car_id','community_name']].groupby('community_name').count()
count_per_zipcode = count_per_zipcode.reset_index()

full_df = pd.merge(count_per_zipcode,full_joined_df,how='inner',on='community_name')
full_df = full_df.rename(columns={'finn_car_id_x':'count_customers'})

# %%
#Create the hexbin map
hex_map(plot=plot,
        df=full_df, 
        scale=scale,
        leg_label='Location of Customers')

# %%
#Create the bubble map. In this case, circle radius is defined by the amount of fatalities. Any column can be chosen to define the radius.
#bubble_map(plot=plot,
#           df=full_df,
#           radius_col='count_customers', 
#           leg_label='Amount of Customers per Zipcode',
#           long='long',
#           lat='lat',
#           scale=scale)

# %%
show(plot)
# Out:
# WARNING:bokeh.core.serialization:out of range integer may result in loss of precision
# WARNING:bokeh.core.serialization:out of range integer may result in loss of precision
#   <div id="4bebfb9c-b9e5-474a-8ea1-5a1e2eee204b" data-root-id="p1228" style="display: contents;"></div>

# %%
output_notebook()
save(plot)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1741">Loading BokehJS ...</span>
#     </div>
# WARNING:bokeh.core.serialization:out of range integer may result in loss of precision
# WARNING:bokeh.core.serialization:out of range integer may result in loss of precision
# '/Users/lenasommer/Documents/Arbeit/Finn /geographic_optimization/plot.html'

# %%
show(plot)
# Out:
# WARNING:bokeh.core.serialization:out of range integer may result in loss of precision
# WARNING:bokeh.core.serialization:out of range integer may result in loss of precision
#   <div id="3635eb11-8ab6-485f-a28c-896239735682" data-root-id="p1228" style="display: contents;"></div>
# WARNING:bokeh.core.serialization:out of range integer may result in loss of precision
# WARNING:bokeh.core.serialization:out of range integer may result in loss of precision
